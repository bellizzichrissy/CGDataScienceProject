# %%
# https://pokeapi.co/api/v2/ability/{id or name}/
# Don't modify this cell.
# Dependencies and Setup
#Data for all 898 pokemon

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
from pprint import pprint
#import pokepy
from random import randint

#Hitting the API and pulling down data for all pokemon in the specified range in json format
base_url = "https://pokeapi.co/api/v2/pokemon/"
pokemon = []
for i in range(1,899):
    req = requests.get(base_url + str(i))
    pokemon.append(req.json())

# %%
#Data for all 898 pokemon
#Making a list
pokemon_all=[]


for entry in pokemon:
    pokemon_dict={}
    pokemon_dict["name"]=entry["name"]
    pokemon_dict["id"]=entry["id"]
    pokemon_dict["height"]=entry["height"]
    pokemon_dict["weight"]=entry["weight"]
    pokemon_dict["base_experience"]=entry["base_experience"]
    pokemon_dict["stats_hp"]=entry["stats"][0]["base_stat"]
    pokemon_dict["stats_attack"]=entry["stats"][1]["base_stat"]
    pokemon_dict["stats_defense"]=entry["stats"][2]["base_stat"]
    pokemon_dict["stats_special_attack"]=entry["stats"][3]["base_stat"]
    pokemon_dict["stats_special_defense"]=entry["stats"][4]["base_stat"]
    pokemon_dict["stats_speed"]=entry["stats"][5]["base_stat"]
    types=entry["types"]
    type_array=[]
    for t in types:
        type_name=t["type"]["name"]
        type_array.append(type_name)
    pokemon_dict["types"]=type_array

    pokemon_all.append(pokemon_dict)
pokemon_df=pd.DataFrame(pokemon_all)
print(len(pokemon_df))
# Out:
# 898

# %%
pokemon_df
# Out:
#            name   id  height  weight  base_experience  stats_hp  stats_attack  \
# 0     bulbasaur    1       7      69               64        45            49
# 1       ivysaur    2      10     130              142        60            62
# 2      venusaur    3      20    1000              236        80            82
# 3    charmander    4       6      85               62        39            52
# 4    charmeleon    5      11     190              142        58            64
# ..          ...  ...     ...     ...              ...       ...           ...
# 893   regieleki  894      12    1450              290        80           100
# 894   regidrago  895      21    2000              290       200           100
# 895   glastrier  896      22    8000              290       100           145
# 896   spectrier  897      20     445              290       100            65
# 897     calyrex  898      11      77              250       100            80
#
# ...

# %%
# https://pokeapi.co/api/v2/ability/{id or name}/
# Don't modify this cell.
# Dependencies and Setup
#1st generation = first 151 pokemon

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
from pprint import pprint
#import pokepy
from random import randint

#Hitting the API and pulling down data for all pokemon in the specified range in json format
base_url = "https://pokeapi.co/api/v2/pokemon/"
pokemon1 = []
for i in range(1,152):
    req = requests.get(base_url + str(i))
    pokemon1.append(req.json())

# %%
#1st generation = first 151 pokemon
#Making a list
pokemon_gen1=[]


for entry in pokemon1:
    pokemon_dict={}
    pokemon_dict["name"]=entry["name"]
    pokemon_dict["id"]=entry["id"]
    pokemon_dict["height"]=entry["height"]
    pokemon_dict["weight"]=entry["weight"]
    pokemon_dict["base_experience"]=entry["base_experience"]
    pokemon_dict["stats_hp"]=entry["stats"][0]["base_stat"]
    pokemon_dict["stats_attack"]=entry["stats"][1]["base_stat"]
    pokemon_dict["stats_defense"]=entry["stats"][2]["base_stat"]
    pokemon_dict["stats_special_attack"]=entry["stats"][3]["base_stat"]
    pokemon_dict["stats_special_defense"]=entry["stats"][4]["base_stat"]
    pokemon_dict["stats_speed"]=entry["stats"][5]["base_stat"]
    types=entry["types"]
    type_array=[]
    for t in types:
        type_name=t["type"]["name"]
        type_array.append(type_name)
    pokemon_dict["types"]=type_array

    pokemon_gen1.append(pokemon_dict)
pokemon_df1=pd.DataFrame(pokemon_gen1)
print(len(pokemon_df1))
# Out:
# 151

# %%
pokemon_df1
# Out:
#            name   id  height  weight  base_experience  stats_hp  stats_attack  \
# 0     bulbasaur    1       7      69               64        45            49
# 1       ivysaur    2      10     130              142        60            62
# 2      venusaur    3      20    1000              236        80            82
# 3    charmander    4       6      85               62        39            52
# 4    charmeleon    5      11     190              142        58            64
# ..          ...  ...     ...     ...              ...       ...           ...
# 146     dratini  147      18      33               60        41            64
# 147   dragonair  148      40     165              147        61            84
# 148   dragonite  149      22    2100              270        91           134
# 149      mewtwo  150      20    1220              306       106           110
# 150         mew  151       4      40              270       100           100
#
# ...

# %%
# https://pokeapi.co/api/v2/ability/{id or name}/
# Don't modify this cell.
# Dependencies and Setup
#2nd generation = pokemon 152-251

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
from pprint import pprint
#import pokepy
from random import randint

#Hitting the API and pulling down data for all pokemon in the specified range in json format
base_url = "https://pokeapi.co/api/v2/pokemon/"
pokemon2 = []
for i in range(152,252):
    req = requests.get(base_url + str(i))
    pokemon2.append(req.json())

# %%
#2nd generation = pokemon 152-251
#Making a list
pokemon_gen2=[]


for entry in pokemon2:
    pokemon_dict={}
    pokemon_dict["name"]=entry["name"]
    pokemon_dict["id"]=entry["id"]
    pokemon_dict["height"]=entry["height"]
    pokemon_dict["weight"]=entry["weight"]
    pokemon_dict["base_experience"]=entry["base_experience"]
    pokemon_dict["stats_hp"]=entry["stats"][0]["base_stat"]
    pokemon_dict["stats_attack"]=entry["stats"][1]["base_stat"]
    pokemon_dict["stats_defense"]=entry["stats"][2]["base_stat"]
    pokemon_dict["stats_special_attack"]=entry["stats"][3]["base_stat"]
    pokemon_dict["stats_special_defense"]=entry["stats"][4]["base_stat"]
    pokemon_dict["stats_speed"]=entry["stats"][5]["base_stat"]
    types=entry["types"]
    type_array=[]
    for t in types:
        type_name=t["type"]["name"]
        type_array.append(type_name)
    pokemon_dict["types"]=type_array

    pokemon_gen2.append(pokemon_dict)
pokemon_df2=pd.DataFrame(pokemon_gen2)
print(len(pokemon_df2))
# Out:
# 100

# %%
pokemon_df2
# Out:
#          name   id  height  weight  base_experience  stats_hp  stats_attack  \
# 0   chikorita  152       9      64               64        45            49
# 1     bayleef  153      12     158              142        60            62
# 2    meganium  154      18    1005              236        80            82
# 3   cyndaquil  155       5      79               62        39            52
# 4     quilava  156       9     190              142        58            64
# ..        ...  ...     ...     ...              ...       ...           ...
# 95    pupitar  247      12    1520              144        70            84
# 96  tyranitar  248      20    2020              270       100           134
# 97      lugia  249      52    2160              306       106            90
# 98      ho-oh  250      38    1990              306       106           130
# 99     celebi  251       6      50              270       100           100
#
# ...

# %%
# https://pokeapi.co/api/v2/ability/{id or name}/
# Don't modify this cell.
# Dependencies and Setup
#3rd generation = pokemon 252-386

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import json
import requests
import time
from pprint import pprint
#import pokepy
from random import randint

#Hitting the API and pulling down data for all pokemon in the specified range in json format
base_url = "https://pokeapi.co/api/v2/pokemon/"
pokemon3 = []
for i in range(252,387):
    req = requests.get(base_url + str(i))
    pokemon3.append(req.json())

# %%
#3rd generation = pokemon 252-386
#Making a list
pokemon_gen3=[]


for entry in pokemon3:
    pokemon_dict={}
    pokemon_dict["name"]=entry["name"]
    pokemon_dict["id"]=entry["id"]
    pokemon_dict["height"]=entry["height"]
    pokemon_dict["weight"]=entry["weight"]
    pokemon_dict["base_experience"]=entry["base_experience"]
    pokemon_dict["stats_hp"]=entry["stats"][0]["base_stat"]
    pokemon_dict["stats_attack"]=entry["stats"][1]["base_stat"]
    pokemon_dict["stats_defense"]=entry["stats"][2]["base_stat"]
    pokemon_dict["stats_special_attack"]=entry["stats"][3]["base_stat"]
    pokemon_dict["stats_special_defense"]=entry["stats"][4]["base_stat"]
    pokemon_dict["stats_speed"]=entry["stats"][5]["base_stat"]
    types=entry["types"]
    type_array=[]
    for t in types:
        type_name=t["type"]["name"]
        type_array.append(type_name)
    pokemon_dict["types"]=type_array

    pokemon_gen3.append(pokemon_dict)
pokemon_df3=pd.DataFrame(pokemon_gen3)
print(len(pokemon_df3))
# Out:
# 135

# %%
pokemon_df3
# Out:
#               name   id  height  weight  base_experience  stats_hp  \
# 0          treecko  252       5      50               62        40
# 1          grovyle  253       9     216              142        50
# 2         sceptile  254      17     522              239        70
# 3          torchic  255       4      25               62        45
# 4        combusken  256       9     195              142        60
# ..             ...  ...     ...     ...              ...       ...
# 130         kyogre  382      45    3520              302       100
# 131        groudon  383      35    9500              302       100
# 132       rayquaza  384      70    2065              306       105
# 133        jirachi  385       3      11              270       100
# 134  deoxys-normal  386      17     608              270        50
#
#      stats_attack  stats_defense  stats_special_attack  stats_special_defense  \
# 0              45             35                    65                     55
# ...

# %%
# https://pokeapi.co/api/v2/ability/{id or name}/
# Don't modify this cell.
# Dependencies and Setup
#4th generation = pokemon 387-493

#Hitting the API and pulling down data for all pokemon in the specified range in json format
base_url = "https://pokeapi.co/api/v2/pokemon/"
pokemon4 = []
for i in range(387,494):
    req = requests.get(base_url + str(i))
    pokemon4.append(req.json())

# %%
#4th generation = pokemon 387-493
#Making a list
pokemon_gen4=[]


for entry in pokemon4:
    pokemon_dict={}
    pokemon_dict["name"]=entry["name"]
    pokemon_dict["id"]=entry["id"]
    pokemon_dict["height"]=entry["height"]
    pokemon_dict["weight"]=entry["weight"]
    pokemon_dict["base_experience"]=entry["base_experience"]
    pokemon_dict["stats_hp"]=entry["stats"][0]["base_stat"]
    pokemon_dict["stats_attack"]=entry["stats"][1]["base_stat"]
    pokemon_dict["stats_defense"]=entry["stats"][2]["base_stat"]
    pokemon_dict["stats_special_attack"]=entry["stats"][3]["base_stat"]
    pokemon_dict["stats_special_defense"]=entry["stats"][4]["base_stat"]
    pokemon_dict["stats_speed"]=entry["stats"][5]["base_stat"]
    types=entry["types"]
    type_array=[]
    for t in types:
        type_name=t["type"]["name"]
        type_array.append(type_name)
    pokemon_dict["types"]=type_array

    pokemon_gen4.append(pokemon_dict)
pokemon_df4=pd.DataFrame(pokemon_gen4)
print(len(pokemon_df4))
# Out:
# 107

# %%
pokemon_df4
# Out:
#              name   id  height  weight  base_experience  stats_hp  \
# 0         turtwig  387       4     102               64        55
# 1          grotle  388      11     970              142        75
# 2        torterra  389      22    3100              236        95
# 3        chimchar  390       5      62               62        44
# 4        monferno  391       9     220              142        64
# ..            ...  ...     ...     ...              ...       ...
# 102        phione  489       4      31              216        80
# 103       manaphy  490       3      14              270       100
# 104       darkrai  491      15     505              270        70
# 105  shaymin-land  492       2      21              270       100
# 106        arceus  493      32    3200              324       120
#
#      stats_attack  stats_defense  stats_special_attack  stats_special_defense  \
# 0              68             64                    45                     55
# ...

# %%
# https://pokeapi.co/api/v2/ability/{id or name}/
# Don't modify this cell.
# Dependencies and Setup
#5th generation = pokemon 494-649


#Hitting the API and pulling down data for all pokemon in the specified range in json format
base_url = "https://pokeapi.co/api/v2/pokemon/"
pokemon5 = []
for i in range(494,650):
    req = requests.get(base_url + str(i))
    pokemon5.append(req.json())

# %%
#5th generation = pokemon 494-649
#Making a list
pokemon_gen5=[]


for entry in pokemon5:
    pokemon_dict={}
    pokemon_dict["name"]=entry["name"]
    pokemon_dict["id"]=entry["id"]
    pokemon_dict["height"]=entry["height"]
    pokemon_dict["weight"]=entry["weight"]
    pokemon_dict["base_experience"]=entry["base_experience"]
    pokemon_dict["stats_hp"]=entry["stats"][0]["base_stat"]
    pokemon_dict["stats_attack"]=entry["stats"][1]["base_stat"]
    pokemon_dict["stats_defense"]=entry["stats"][2]["base_stat"]
    pokemon_dict["stats_special_attack"]=entry["stats"][3]["base_stat"]
    pokemon_dict["stats_special_defense"]=entry["stats"][4]["base_stat"]
    pokemon_dict["stats_speed"]=entry["stats"][5]["base_stat"]
    types=entry["types"]
    type_array=[]
    for t in types:
        type_name=t["type"]["name"]
        type_array.append(type_name)
    pokemon_dict["types"]=type_array

    pokemon_gen5.append(pokemon_dict)
pokemon_df5=pd.DataFrame(pokemon_gen5)
print(len(pokemon_df5))
# Out:
# 156

# %%
pokemon_df5
# Out:
#                    name   id  height  weight  base_experience  stats_hp  \
# 0               victini  494       4      40              270       100
# 1                 snivy  495       6      81               62        45
# 2               servine  496       8     160              145        60
# 3             serperior  497      33     630              238        75
# 4                 tepig  498       5      99               62        65
# ..                  ...  ...     ...     ...              ...       ...
# 151  landorus-incarnate  645      15     680              270        89
# 152              kyurem  646      30    3250              297       125
# 153     keldeo-ordinary  647      14     485              261        91
# 154       meloetta-aria  648       6      65              270       100
# 155            genesect  649      15     825              270        71
#
#      stats_attack  stats_defense  stats_special_attack  stats_special_defense  \
# ...

# %%
# https://pokeapi.co/api/v2/ability/{id or name}/
# Don't modify this cell.
# Dependencies and Setup
#6th generation = pokemon 650-721


#Hitting the API and pulling down data for all pokemon in the specified range in json format
base_url = "https://pokeapi.co/api/v2/pokemon/"
pokemon6 = []
for i in range(650,722):
    req = requests.get(base_url + str(i))
    pokemon6.append(req.json())

# %%
#6th generation = pokemon 650-721
#Making a list
pokemon_gen6=[]


for entry in pokemon6:
    pokemon_dict={}
    pokemon_dict["name"]=entry["name"]
    pokemon_dict["id"]=entry["id"]
    pokemon_dict["height"]=entry["height"]
    pokemon_dict["weight"]=entry["weight"]
    pokemon_dict["base_experience"]=entry["base_experience"]
    pokemon_dict["stats_hp"]=entry["stats"][0]["base_stat"]
    pokemon_dict["stats_attack"]=entry["stats"][1]["base_stat"]
    pokemon_dict["stats_defense"]=entry["stats"][2]["base_stat"]
    pokemon_dict["stats_special_attack"]=entry["stats"][3]["base_stat"]
    pokemon_dict["stats_special_defense"]=entry["stats"][4]["base_stat"]
    pokemon_dict["stats_speed"]=entry["stats"][5]["base_stat"]
    types=entry["types"]
    type_array=[]
    for t in types:
        type_name=t["type"]["name"]
        type_array.append(type_name)
    pokemon_dict["types"]=type_array

    pokemon_gen6.append(pokemon_dict)
pokemon_df6=pd.DataFrame(pokemon_gen6)
print(len(pokemon_df6))
# Out:
# 72

# %%
pokemon_df6
# Out:
#           name   id  height  weight  base_experience  stats_hp  stats_attack  \
# 0      chespin  650       4      90               63        56            61
# 1    quilladin  651       7     290              142        61            78
# 2   chesnaught  652      16     900              239        88           107
# 3     fennekin  653       4      94               61        40            45
# 4      braixen  654      10     145              143        59            59
# ..         ...  ...     ...     ...              ...       ...           ...
# 67     yveltal  717      58    2030              306       126           131
# 68     zygarde  718      50    3050              270       108           100
# 69     diancie  719       7      88              270        50           100
# 70       hoopa  720       5      90              270        80           110
# 71   volcanion  721      17    1950              270        80           110
#
# ...

# %%
# https://pokeapi.co/api/v2/ability/{id or name}/
# Don't modify this cell.
# Dependencies and Setup
#7th generation = pokemon 722-809


#Hitting the API and pulling down data for all pokemon in the specified range in json format
base_url = "https://pokeapi.co/api/v2/pokemon/"
pokemon7 = []
for i in range(722,810):
    req = requests.get(base_url + str(i))
    pokemon7.append(req.json())

# %%
#7th generation = pokemon 722-809
#Making a list
pokemon_gen7=[]


for entry in pokemon7:
    pokemon_dict={}
    pokemon_dict["name"]=entry["name"]
    pokemon_dict["id"]=entry["id"]
    pokemon_dict["height"]=entry["height"]
    pokemon_dict["weight"]=entry["weight"]
    pokemon_dict["base_experience"]=entry["base_experience"]
    pokemon_dict["stats_hp"]=entry["stats"][0]["base_stat"]
    pokemon_dict["stats_attack"]=entry["stats"][1]["base_stat"]
    pokemon_dict["stats_defense"]=entry["stats"][2]["base_stat"]
    pokemon_dict["stats_special_attack"]=entry["stats"][3]["base_stat"]
    pokemon_dict["stats_special_defense"]=entry["stats"][4]["base_stat"]
    pokemon_dict["stats_speed"]=entry["stats"][5]["base_stat"]
    types=entry["types"]
    type_array=[]
    for t in types:
        type_name=t["type"]["name"]
        type_array.append(type_name)
    pokemon_dict["types"]=type_array

    pokemon_gen7.append(pokemon_dict)
pokemon_df7=pd.DataFrame(pokemon_gen7)
print(len(pokemon_df7))
# Out:
# 88

# %%
pokemon_df7
# Out:
#            name   id  height  weight  base_experience  stats_hp  stats_attack  \
# 0        rowlet  722       3      15               64        68            55
# 1       dartrix  723       7     160              147        78            75
# 2     decidueye  724      16     366              239        78           107
# 3        litten  725       4      43               64        45            65
# 4      torracat  726       7     250              147        65            85
# ..          ...  ...     ...     ...              ...       ...           ...
# 83    stakataka  805      55    8200              257        61           131
# 84  blacephalon  806      18     130              257        53           127
# 85      zeraora  807      15     445              270        88           112
# 86       meltan  808       2      80              135        46            65
# 87     melmetal  809      25    8000              270       135           143
#
# ...

# %%
# https://pokeapi.co/api/v2/ability/{id or name}/
# Don't modify this cell.
# Dependencies and Setup
#8th generation = pokemon 810-898


#Hitting the API and pulling down data for all pokemon in the specified range in json format
base_url = "https://pokeapi.co/api/v2/pokemon/"
pokemon8 = []
for i in range(810,899):
    req = requests.get(base_url + str(i))
    pokemon8.append(req.json())

# %%
#8th generation = pokemon 810-898
#Making a list
pokemon_gen8=[]


for entry in pokemon8:
    pokemon_dict={}
    pokemon_dict["name"]=entry["name"]
    pokemon_dict["id"]=entry["id"]
    pokemon_dict["height"]=entry["height"]
    pokemon_dict["weight"]=entry["weight"]
    pokemon_dict["base_experience"]=entry["base_experience"]
    pokemon_dict["stats_hp"]=entry["stats"][0]["base_stat"]
    pokemon_dict["stats_attack"]=entry["stats"][1]["base_stat"]
    pokemon_dict["stats_defense"]=entry["stats"][2]["base_stat"]
    pokemon_dict["stats_special_attack"]=entry["stats"][3]["base_stat"]
    pokemon_dict["stats_special_defense"]=entry["stats"][4]["base_stat"]
    pokemon_dict["stats_speed"]=entry["stats"][5]["base_stat"]
    types=entry["types"]
    type_array=[]
    for t in types:
        type_name=t["type"]["name"]
        type_array.append(type_name)
    pokemon_dict["types"]=type_array

    pokemon_gen8.append(pokemon_dict)
pokemon_df8=pd.DataFrame(pokemon_gen8)
print(len(pokemon_df8))
# Out:
# 89

# %%
pokemon_df8
# Out:
#          name   id  height  weight  base_experience  stats_hp  stats_attack  \
# 0     grookey  810       3      50               62        50            65
# 1    thwackey  811       7     140              147        70            85
# 2   rillaboom  812      21     900              265       100           125
# 3   scorbunny  813       3      45               62        50            71
# 4      raboot  814       6      90              147        65            86
# ..        ...  ...     ...     ...              ...       ...           ...
# 84  regieleki  894      12    1450              290        80           100
# 85  regidrago  895      21    2000              290       200           100
# 86  glastrier  896      22    8000              290       100           145
# 87  spectrier  897      20     445              290       100            65
# 88    calyrex  898      11      77              250       100            80
#
# ...

# %%
#Making a list
pokemon_temp=[]
for entry in pokemon:
    #if entry["cod"]=="404":
        #continue
    pokemon_dict={}
    pokemon_dict["height"]=(entry["height"])
    print(entry["height"])
    pokemon_dict["weight"]=entry["weight"]
    print(entry["weight"])
    pokemon_dict["name"]=entry["name"]
    print(entry["name"])
    pokemon_temp.append(pokemon_dict)
pokemon_df=pd.DataFrame(pokemon_temp)
pokemon_df.head()
print(len(pokemon_df))
# Out:
# 7
# 69
# bulbasaur
# 10
# 130
# ivysaur
# 2

# %%
pokemon_df
# Out:
#    height  weight       name
# 0       7      69  bulbasaur
# 1      10     130    ivysaur

# %%
base_url = "https://pokeapi.co/api/v2/pokemon/"

for i in range(1,2):
    req = requests.get(base_url + str(i))
    pprint(req.json())
# Out:
# {'abilities': [{'ability': {'name': 'overgrow',
#                             'url': 'https://pokeapi.co/api/v2/ability/65/'},
#                 'is_hidden': False,
#                 'slot': 1},
#                {'ability': {'name': 'chlorophyll',
#                             'url': 'https://pokeapi.co/api/v2/ability/34/'},
#                 'is_hidden': True,
#                 'slot': 3}],
#  'base_experience': 64,
#  'forms': [{'name': 'bulbasaur',
#             'url': 'https://pokeapi.co/api/v2/pokemon-form/1/'}],
#  'game_indices': [{'game_index': 153,
#                    'version': {'name': 'red',
#                                'url': 'https://pokeapi.co/api/v2/version/1/'}},
#                   {'game_index': 153,
#                    'version': {'name': 'blue',
#                                'url': 'https://pokeapi.co/api/v2/version/2/'}},
#                   {'game_index': 153,
#                    'version': {'name': 'yellow',
# ...

# %%
pokemon_temp=[]
for entry in pokemon:
    #if entry["cod"]=="404":
        #continue
    pokemon_dict={}
    pokemon_dict["height"]=(entry["height"])
    print(entry["height"])
    
pokemon_temp.append(pokemon_dict)
pokemon_df=pd.DataFrame(pokemon_temp)
pokemon_df.head()
print(len(pokemon_df))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-940930d3a6c1> in <module>
#       4         #continue
#       5     pokemon_dict={}
# ----> 6     pokemon_dict["height"]=(entry["height"])
#       7     print(entry["height"])
#       8
#
# TypeError: string indices must be integers

# %%
base_url = "https://pokeapi.co/api/v2/pokemon/"


pokemon_list = []

for i in range(1,2):
    req = requests.get(base_url + str(i))
    data = req.json()
    
    
pokemon = json_data['name']
print(pokemon)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-65469f1aa22c> in <module>
#       9
#      10
# ---> 11 pokemon = json_data['name']
#      12 print(pokemon)
#
# NameError: name 'json_data' is not defined

# %%
if pokemon not in pokemon_list:
        pokemon_list.append(pokemon)

# %%
pprint(req.json())

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-61f00593c1ba> in <module>
# ----> 1 seed(1)
#       2 pokenumber = randint(0, 151)
#
# NameError: name 'seed' is not defined

# %%
base_url = "https://pokeapi.co/api/v2/pokemon/"

pokemon_list =  {"name":[],
                "id":[],
                "height":[]}

for i in range(1,2):
    req = requests.get(base_url + str(i)).json()
    
    data = req.json()
    
    pokemon_list["name"].append(data['name'])
    pokemon_list["id"].append(data['id'])
    pokemon_list["height"].append(data['height'])
    
print(pokemon_list)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-c191d418d4b2> in <module>
#       8     req = requests.get(base_url + str(i)).json()
#       9
# ---> 10     data = req.json()
#      11
#      12     pokemon_list["name"].append(data['name'])
#
# AttributeError: 'dict' object has no attribute 'json'
